# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load layoffs data
layoffs = pd.read_csv("../data/layoffs.csv", parse_dates=["date"])

# Load job postings
jobs = pd.read_csv("../data/job_postings.csv", parse_dates=["date"])

# %%
layoffs.head(5)
# Out:
#     company location       date    industry  laid_off
# 0  TechCorp      USA 2023-01-15    Software       120
# 1   EduSoft       UK 2023-02-10      EdTech        80
# 2  HealthIQ    India 2023-03-05  HealthTech        60

# %%
jobs.head(5)
# Out:
#       job_title  industry                 skills  salary location       date
# 0  Data Analyst  Software       SQL,Python,Excel   80000      NYC 2023-01-01
# 1   ML Engineer        AI  Python,TensorFlow,AWS  120000   Remote 2023-01-20

# %%
# Layoffs by industry
layoffs_by_industry = layoffs.groupby("industry")["laid_off"].sum().sort_values(ascending=False)
layoffs_by_industry.plot(kind="bar", title="Total Layoffs by Industry", figsize=(10,5))
plt.tight_layout()
plt.show()

# %%
#Layoffs over Time
layoffs.plot.line(x='date',y='laid_off')
# Out:
# <Axes: xlabel='date'>

# %%
layoffs_by_location = layoffs.groupby("location")["laid_off"].sum().sort_values(ascending=False)
layoffs_by_location.plot(kind="bar", title="Total Layoffs by Industry", figsize=(10,5))
plt.tight_layout()
plt.show()

# %%
# Top job titles
print(jobs["job_title"].value_counts().head())

# Top skills
from collections import Counter
skills = jobs["skills"].dropna().str.split(",").explode().str.strip()
top_skills = pd.Series(Counter(skills)).sort_values(ascending=False).head(10)
top_skills.plot(kind="bar", title="Most In-Demand Skills", figsize=(10,5))
plt.tight_layout()
plt.show()
# Out:
# job_title
# Data Analyst    1
# ML Engineer     1
# Name: count, dtype: int64
